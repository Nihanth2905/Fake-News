# %% [markdown]
# # Fake News Detection EDA
#
# Explore the dataset before training the classifiers.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('../data/train.csv')
data = pd.read_csv(data_path) if data_path.exists() else pd.DataFrame()
data.head()
